# %% [markdown]
# ## AQUA MOTIVATION

# %%
# FIGURE 3

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
sns.set_style("whitegrid")
import matplotlib.ticker as mtick
import matplotlib
import matplotlib.patches as mpatches
# %matplotlib notebook
matplotlib.ticker._mathdefault = lambda x: '\\mathdefault{%s}'%x
#Get Non-Type-3 Fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

legends = ["TRH=4K", "TRH=2K", "TRH=1K"]
                               
#Color Palette
colors = ['#FBD148','#3DB2FF','black', '#34a853']

#Set Font Size
#plt.rc('font', family='serif')
plt.rc('font', size='9.5')

# Read Dataframe
df = pd.read_csv("../stats_scripts/data/rrs_scalability.stat", delimiter='\s+')
#print (df)

# Format for Slowdown (%) ensure 0s stay 0s.
# for i in ['4K','2K','1K']:
#     slowdown_df = df.copy()
#     slowdown_df.loc[slowdown_df[i] == 0, i] = 1
#     slowdown_df[i] = slowdown_df[i]-1
# print (slowdown_df)

# Set position of bar on X axis
#barwidth
barWidth = 0.23
r1 = np.arange(len(df.index))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

#Create Plot
fig = plt.figure(figsize=(10,2.4))
ax = plt.gca()
#Bars
plt.bar(r1, df['4K'], width = barWidth, color=colors[0], label=legends[0],edgecolor='k')
plt.bar(r2, df['2K'], width = barWidth, color=colors[1],label=legends[1],edgecolor='k')
plt.bar(r3, df['1K'], width = barWidth, color=colors[2],label=legends[2],edgecolor='k')

#Y=1 Black Line
ax.plot([-0.75,len(df.index)+0.25], [1,1],lw=1.5,color='black')

# Add xticks on the middle of the group bars
df.at[34,'Expts'] = " "
plt.xticks([(r+barWidth*2) for r in range(len(df.index))], df['Expts'])
ax.set_xlim(-0.75,len(df.index)+0.25)
plt.xticks(rotation = 30,ha='right')

ax.tick_params(axis='x', which='major', labelsize=8)
for tick in ax.xaxis.get_major_ticks():
    tick_str = tick.label1.get_text()
    if( (tick_str == "Spec-18") or (tick_str == "Mix-16") or (tick_str == "Gmean-34")):
        tick.label1.set_weight('bold')


#Add Y-axes labels
plt.ylabel('Norm. Performance', size=9.5)
ax.tick_params(axis='y', which='major', labelsize=8.5)

#Set Y format & limts
#ax.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
ax.set_ylim(0,1.1)
ax.set_yticks([0.2,0.4,0.6,0.8,1])

#grid
ax.axis('on')
ax.xaxis.grid()

#Legend
leg_handles=[]
for i in range(0,3):
    leg_handles.append(mpatches.Patch(facecolor=colors[i], lw=1, label=legends[i], edgecolor='k'))
plt.legend(handles = leg_handles, bbox_to_anchor=(0.5,1.1),frameon=False,loc='center',ncol=4,prop={'size':10})

#Text
#ax.text(35,1.1, 'Gmean', family='serif',size='9.5',weight='bold',
#        ha='center', va='center')


#Figure
plt.tight_layout()
fig.savefig("rrs_scalability.pdf",bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %% [markdown]
# ## AQUA SRIT Performance

# %%
# FIGURE 6

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
sns.set_style("whitegrid")
import matplotlib.ticker as mtick
import matplotlib
# %matplotlib notebook
matplotlib.ticker._mathdefault = lambda x: '\\mathdefault{%s}'%x
import matplotlib.patches as mpatches

#Get Non-Type-3 Fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

legends = ["RRS", "AQUA"]
                               
#Color Palette
colors = ['#FBD148','#3DB2FF','black', '#34a853']

#Set Font Size
#plt.rc('font', family='serif')
plt.rc('font', size='9.5')

# Read Dataframe
df = pd.read_csv("../stats_scripts/data/perf_rq_rrs.stat", delimiter='\s+')
print (df)

# Set position of bar on X axis
#barwidth
barWidth = 0.3
r1 = np.arange(len(df.index))
r2 = [x + barWidth for x in r1]
#r3 = [x + barWidth for x in r2]

#Create Plot
fig = plt.figure(figsize=(10,2.5))
ax = plt.gca()
#Bars
plt.bar(r1, df['RRS'], width = barWidth, color=colors[0], label=legends[0],edgecolor='k')
plt.bar(r2, df['AQUA'], width = barWidth, color=colors[1],label=legends[1],edgecolor='k')

#Y=1 Black Line
ax.plot([-0.75,len(df.index)+0.25], [1,1],lw=1.5,color='black')

# Add xticks on the middle of the group bars
df.at[34,'Expts'] = " "
plt.xticks([(r+barWidth*1) for r in range(len(df.index))], df['Expts'])
ax.set_xlim(-0.75,len(df.index)+0.25)
plt.xticks(rotation = 30,ha='right')

ax.tick_params(axis='x', which='major', labelsize=8)
for tick in ax.xaxis.get_major_ticks():
    tick_str = tick.label1.get_text()
    if( (tick_str == "Spec-18") or (tick_str == "Mix-16") or (tick_str == "Gmean-34")):
        tick.label1.set_weight('bold')


#Add Y-axes labels
plt.ylabel('Norm. Performance', size=9.5)
ax.tick_params(axis='y', which='major', labelsize=8.5)
ax.tick_params(axis='x', which='major', pad=-1)
#Set Y format & limts
#ax.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
ax.set_ylim(0,1.1)
ax.set_yticks([0.2,0.4,0.6,0.8,1])

#grid
ax.axis('on')
ax.xaxis.grid()

#Legend
leg_handles=[]
for i in range(0,2):
    leg_handles.append(mpatches.Patch(facecolor=colors[i], lw=1, label=legends[i], edgecolor='k'))
plt.legend(handles = leg_handles, bbox_to_anchor=(0.5,1.1),frameon=False,loc='center',ncol=4,prop={'size':10})

#Text
#ax.text(35,1.1, 'Gmean', family='serif',size='9.5',weight='bold',
#        ha='center', va='center')


#Figure
plt.tight_layout()
fig.savefig("perf_aqua.pdf",bbox_inches='tight')
plt.show()
# Out:
#         Expts    RRS   AQUA
# 0   perlbench  0.942  0.999
# 1         gcc  0.549  0.949
# 2      bwaves  0.938  1.000
# 3         mcf  0.561  0.985
# 4   cactuBSSN  0.834  1.000
# 5        namd  0.964  1.000
# 6      povray  1.000  1.000
# 7         lbm  0.336  0.836
# 8         wrf  1.000  1.000
# 9     blender  0.413  0.916
# 10  deepsjeng  0.999  1.000
# 11    imagick  0.902  0.994
# 12      leela  1.000  1.000
# 13        nab  0.988  1.000
# 14  exchange2  1.000  1.000
# 15       roms  0.632  0.966
# 16         xz  0.960  1.000
# 17     parest  1.000  1.000
# 18       mix1  0.984  1.000
# 19       mix2  0.965  1.000
# 20       mix3  0.964  1.000
# 21       mix4  0.827  0.998
# 22       mix5  0.779  0.990
# 23       mix6  0.623  0.945
# 24       mix7  0.976  1.000
# 25       mix8  0.934  1.000
# 26       mix9  0.812  0.989
# 27      mix10  0.859  0.992
# 28      mix11  0.469  0.931
# 29      mix12  0.843  0.998
# 30      mix13  0.786  0.969
# 31      mix14  0.667  0.958
# 32      mix15  0.771  0.997
# 33      mix16  0.896  0.998
# 34          .  0.000  0.000
# 35   Gmean-34  0.802  0.982
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %% [markdown]
# ## SRIT MIGRATIONS

# %%
# FIGURE 7

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
sns.set_style("whitegrid")
import matplotlib.ticker as mtick
import matplotlib
# %matplotlib notebook
matplotlib.ticker._mathdefault = lambda x: '\\mathdefault{%s}'%x
import matplotlib.patches as mpatches

#Get Non-Type-3 Fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

legends = ["RRS", "AQUA"]
                               
#Color Palette
colors = ['#FBD148','#3DB2FF','black', '#34a853']

#Set Font Size
#plt.rc('font', family='serif')
plt.rc('font', size='9.5')

# Read Dataframe
df = pd.read_csv("../stats_scripts/data/migrations_rrs_rq.stat", delimiter='\s+')
#print (df)

# Set position of bar on X axis
#barwidth
barWidth = 0.3
r1 = np.arange(len(df.index))
r2 = [x + barWidth for x in r1]
#r3 = [x + barWidth for x in r2]


# Format for Log ensure 0 becomes 1.
log_df = df.copy()
for i in ['RRS','AQUA']:
    log_df.loc[log_df[i] == 0, i] = 1.2
    log_df.at[34,i] = 0
print (log_df)

#Create Plot
fig = plt.figure(figsize=(10,2.5))
ax = plt.gca()
#Bars
plt.bar(r1, log_df['RRS'], width = barWidth, color=colors[0], label=legends[0],edgecolor='k')
plt.bar(r2, log_df['AQUA'], width = barWidth, color=colors[1],label=legends[1],edgecolor='k')

#Y=1 Black Line
#ax.plot([-0.75,len(df.index)+0.25], [1,1],lw=1.5,color='black')

# Add xticks on the middle of the group bars
df.at[34,'Expts'] = " "
plt.xticks([(r+barWidth*1) for r in range(len(df.index))], df['Expts'])
ax.set_xlim(-0.75,len(df.index)+0.25)
plt.xticks(rotation = 30,ha='right')
ax.tick_params(axis='x', which='major', pad=-1)

ax.tick_params(axis='x', which='major', labelsize=8)
for tick in ax.xaxis.get_major_ticks():
    tick_str = tick.label1.get_text()
    if( (tick_str == "Spec-18") or (tick_str == "Mix-16") or (tick_str == "Amean-34")):
        tick.label1.set_weight('bold')


#Add Y-axes labels
plt.ylabel('Row Migration Per 64ms', size=9.5)
ax.tick_params(axis='y', which='major', labelsize=8.5)

#Set Y format & limts
plt.yscale("log")
#ax.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
ax.set_ylim(1,10**5)
ax.set_yticks([10,10**2,10**3,10**4,10**5])

#grid
ax.axis('on')
ax.xaxis.grid()

#Legend
leg_handles=[]
for i in range(0,2):
    leg_handles.append(mpatches.Patch(facecolor=colors[i], lw=1, label=legends[i], edgecolor='k'))
plt.legend(handles = leg_handles, bbox_to_anchor=(0.5,1.1),frameon=False,loc='center',ncol=4,prop={'size':10})

#0 for RRS
#for i in [6,8,12,14,17]:
#    ax.text(i,2, '0',size='7.5',
#            ha='center', va='center')

#0 for AQUA
#for i in [6,8,10,12,14,16,17,20]:
#    ax.text(i+0.35,2, '0',size='7.5',
#            ha='center', va='center')
ax.text(4+0.35,2, '0',size='7.5',
            ha='center', va='center')


#Figure
plt.tight_layout()
fig.savefig("migrations_aqua.pdf",bbox_inches='tight')
plt.show()
# Out:
#         Expts          RRS         AQUA
# 0   perlbench   3520.35000    16.738000
# 1         gcc  19733.90000  1980.800000
# 2      bwaves   2762.16000     4.525500
# 3         mcf  22421.30000  1833.230000
# 4   cactuBSSN   9434.25000     0.880128
# 5        namd   1580.79000     6.852290
# 6      povray     11.68800     3.896320
# 7         lbm  29502.60000  7444.050000
# 8         wrf     10.71090     3.570300
# 9     blender  26409.40000  3816.910000
# 10  deepsjeng     28.80710     2.060540
# 11    imagick   6148.70000   332.884000
# 12      leela      5.10624     1.702400
# 13        nab    433.83100     5.543420
# 14  exchange2      8.47104     2.823550
# 15       roms  16815.50000  1540.960000
# 16         xz   2131.29000     1.793280
# 17     parest     12.22620     4.075520
# 18       mix1   3731.42000    80.882200
# 19       mix2   1917.64000    40.313500
# 20       mix3   2915.23000     4.160380
# 21       mix4  11307.60000   185.814000
# 22       mix5  13470.60000   663.083000
# 23       mix6  28724.10000  5353.710000
# 24       mix7   2661.77000    86.340700
# 25       mix8   4999.61000    14.065700
# 26       mix9   9453.27000   578.870000
# 27      mix10  11165.40000   637.489000
# 28      mix11  25616.30000  3500.500000
# 29      mix12   9191.98000   210.989000
# 30      mix13  25496.20000  4001.200000
# 31      mix14  27578.70000  4658.740000
# 32      mix15  11402.50000   197.525000
# 33      mix16   7207.75000   150.312000
# 34          .      0.00000     0.000000
# 35      Amean   9935.62000  1099.040000
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %% [markdown]
# ## AQUA DRAM

# %%
# FIGURE 9

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
sns.set_style("whitegrid")
import matplotlib.ticker as mtick
import matplotlib
# %matplotlib notebook
matplotlib.ticker._mathdefault = lambda x: '\\mathdefault{%s}'%x
import matplotlib.patches as mpatches

#Get Non-Type-3 Fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

legends = ["AQUA - SRAM", "AQUA - Memory Mapped"]
                               
#Color Palette
colors = ['#FBD148','#3DB2FF','black', '#34a853']

#Set Font Size
#plt.rc('font', family='serif')
plt.rc('font', size='9.5')

# Read Dataframe
df = pd.read_csv("../stats_scripts/data/perf_rq_drit.stat", delimiter='\s+')
print (df)

# Set position of bar on X axis
#barwidth
barWidth = 0.3
r1 = np.arange(len(df.index))
r2 = [x + barWidth for x in r1]
#r3 = [x + barWidth for x in r2]

#Create Plot
fig = plt.figure(figsize=(10,2.5))
ax = plt.gca()
#Bars
plt.bar(r1, df['AQUA-SRAM'], width = barWidth, color=colors[1], label=legends[0],edgecolor='k')
plt.bar(r2, df['AQUA-DRAM'], width = barWidth, color=colors[2],label=legends[1],edgecolor='k')

#Y=1 Black Line
ax.plot([-0.75,len(df.index)+0.25], [1,1],lw=1.5,color='black')

# Add xticks on the middle of the group bars
df.at[34,'Expts'] = " "
plt.xticks([(r+barWidth*1) for r in range(len(df.index))], df['Expts'])
ax.set_xlim(-0.75,len(df.index)+0.25)
plt.xticks(rotation = 30,ha='right')

ax.tick_params(axis='x', which='major', labelsize=8)
for tick in ax.xaxis.get_major_ticks():
    tick_str = tick.label1.get_text()
    if( (tick_str == "Spec-18") or (tick_str == "Mix-16") or (tick_str == "Gmean-34")):
        tick.label1.set_weight('bold')


#Add Y-axes labels
plt.ylabel('Norm. Performance', size=9.5)
ax.tick_params(axis='y', which='major', labelsize=8.5)
ax.tick_params(axis='x', which='major', pad=-1)
#Set Y format & limts
#ax.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
ax.set_ylim(0.5,1.1)
ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1])

#grid
ax.axis('on')
ax.xaxis.grid()

#Legend
leg_handles=[]
for i in range(0,2):
    leg_handles.append(mpatches.Patch(facecolor=colors[i+1], lw=1, label=legends[i], edgecolor='k'))
plt.legend(handles = leg_handles, bbox_to_anchor=(0.5,1.1),frameon=False,loc='center',ncol=4,prop={'size':10})

#Text
#ax.text(35,1.1, 'Gmean', family='serif',size='9.5',weight='bold',
#        ha='center', va='center')


#Figure
plt.tight_layout()
fig.savefig("perf_aqua_dram.pdf",bbox_inches='tight')
plt.show()
# Out:
#         Expts  AQUA-SRAM  AQUA-DRAM
# 0   perlbench      0.999      0.998
# 1         gcc      0.949      0.939
# 2      bwaves      1.000      1.001
# 3         mcf      0.985      0.964
# 4   cactuBSSN      1.000      0.998
# 5        namd      1.000      0.998
# 6      povray      1.000      1.000
# 7         lbm      0.836      0.800
# 8         wrf      1.000      1.000
# 9     blender      0.916      0.903
# 10  deepsjeng      1.000      1.000
# 11    imagick      0.994      0.993
# 12      leela      1.000      1.000
# 13        nab      1.000      0.999
# 14  exchange2      1.000      1.000
# 15       roms      0.966      0.978
# 16         xz      1.000      0.999
# 17     parest      1.000      1.000
# 18       mix1      1.000      0.999
# 19       mix2      1.000      0.999
# 20       mix3      1.000      1.000
# 21       mix4      0.998      0.997
# 22       mix5      0.990      0.988
# 23       mix6      0.945      0.940
# 24       mix7      1.000      0.999
# 25       mix8      1.000      0.999
# 26       mix9      0.989      0.987
# 27      mix10      0.992      0.991
# 28      mix11      0.931      0.926
# 29      mix12      0.998      0.998
# 30      mix13      0.969      0.968
# 31      mix14      0.958      0.954
# 32      mix15      0.997      0.996
# 33      mix16      0.998      0.997
# 34          .      0.000      0.000
# 35   Gmean-34      0.982      0.979
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %% [markdown]
# ## AQUA DRAM HitLoc

# %%
# FIGURE 10

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
sns.set_style("whitegrid")
import matplotlib.ticker as mtick
import matplotlib
# %matplotlib notebook
matplotlib.ticker._mathdefault = lambda x: '\\mathdefault{%s}'%x
import matplotlib.patches as mpatches

#Get Non-Type-3 Fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

legends = ["Bloom-Filter Entry = 0", "FPT-Cache Hit","Singleton in FPT-Cache", "DRAM Access"]
                               
#Color Palette
colors = ['#FBD148','#3DB2FF','black', '#34a853']

#Set Font Size
#plt.rc('font', family='serif')
plt.rc('font', size='9.5')

# Read Dataframe
df = pd.read_csv("../stats_scripts/data/hitloc_rq_drit.stat", delimiter='\s+')
# df['BF-0'] = df['BF-0'].str.rstrip('%').astype('float') / 100.0
# df['Cache-Hit'] = df['Cache-Hit'].str.rstrip('%').astype('float') / 100.0
# df['Singleton'] = df['Singleton'].str.rstrip('%').astype('float') / 100.0
# df['DRAM-Acco'] = df['DRAM-Acco'].str.rstrip('%').astype('float') / 100.0
print (df)

# Set position of bar on X axis
#barwidth
barWidth = 0.45
r1 = np.arange(len(df.index))
r2 = [x + barWidth for x in r1]
#r3 = [x + barWidth for x in r2]

#Create Plot
fig = plt.figure(figsize=(10,2.5))
ax = plt.gca()
#Bars
plt.bar(r1, df['DRAM-Acco']+df['Singleton']+df['Cache-Hit']+df['BF-0'], width = barWidth, color=colors[3],label=legends[3],edgecolor='k')
plt.bar(r1, df['Singleton']+df['Cache-Hit']+df['BF-0'], width = barWidth, color=colors[2],label=legends[2],edgecolor='k')
plt.bar(r1, df['Cache-Hit']+df['BF-0'], width = barWidth, color=colors[1],label=legends[1],edgecolor='k')
plt.bar(r1, df['BF-0'], width = barWidth, color=colors[0], label=legends[0],edgecolor='k')


#Y=1 Black Line
ax.plot([-0.75,len(df.index)+0.25], [1,1],lw=1.5,color='black')

# Add xticks on the middle of the group bars
df.at[34,'Expts'] = " "
plt.xticks([(r+barWidth*1) for r in range(len(df.index))], df['Expts'])
ax.set_xlim(-0.75,len(df.index)+0.25)
plt.xticks(rotation = 30,ha='right')

ax.tick_params(axis='x', which='major', labelsize=8)
for tick in ax.xaxis.get_major_ticks():
    tick_str = tick.label1.get_text()
    if( (tick_str == "Spec-18") or (tick_str == "Mix-16") or (tick_str == "Amean-34")):
        tick.label1.set_weight('bold')


#Add Y-axes labels
plt.ylabel('FPT Accesses (%)', size=9.5)
ax.tick_params(axis='y', which='major', labelsize=8.5)
ax.tick_params(axis='x', which='major', pad=-1)
#Set Y format & limts
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
ax.set_ylim(0.0,1.05)
#ax.set_yticks([0.75,0.8,0.85,0.9,0.95,1])

#grid
ax.axis('on')
ax.xaxis.grid()

#Legend
leg_handles=[]
for i in range(0,4):
    leg_handles.append(mpatches.Patch(facecolor=colors[i], lw=1, label=legends[i], edgecolor='k'))
plt.legend(handles = leg_handles, bbox_to_anchor=(0.5,1.1),frameon=False,loc='center',ncol=4,prop={'size':10})

#Text
#ax.text(35,1.1, 'Gmean', family='serif',size='9.5',weight='bold',
#        ha='center', va='center')


#Figure
plt.tight_layout()
fig.savefig("hitloc_aqua_dram.pdf",bbox_inches='tight')
plt.show()
# Out:
#         Expts    BF-0  Cache-Hit  Singleton  DRAM-Acco
# 0   perlbench  0.9996     0.0004     0.0000     0.0000
# 1         gcc  0.7935     0.1967     0.0096     0.0002
# 2      bwaves  0.9995     0.0005     0.0000     0.0000
# 3         mcf  0.7134     0.2824     0.0042     0.0000
# 4   cactuBSSN  1.0000     0.0000     0.0000     0.0000
# 5        namd  0.9999     0.0001     0.0000     0.0000
# 6      povray  1.0000     0.0000     0.0000     0.0000
# 7         lbm  0.6701     0.2455     0.0786     0.0058
# 8         wrf  1.0000     0.0000     0.0000     0.0000
# 9     blender  0.4911     0.4983     0.0102     0.0005
# 10  deepsjeng  1.0000     0.0000     0.0000     0.0000
# 11    imagick  0.9746     0.0254     0.0000     0.0000
# 12      leela  1.0000     0.0000     0.0000     0.0000
# 13        nab  0.9998     0.0002     0.0000     0.0000
# 14  exchange2  1.0000     0.0000     0.0000     0.0000
# 15       roms  0.8499     0.1480     0.0020     0.0000
# 16         xz  1.0000     0.0000     0.0000     0.0000
# 17     parest  1.0000     0.0000     0.0000     0.0000
# 18       mix1  0.9936     0.0063     0.0000     0.0000
# 19       mix2  0.9991     0.0009     0.0000     0.0000
# 20       mix3  1.0000     0.0000     0.0000     0.0000
# 21       mix4  0.9987     0.0011     0.0002     0.0000
# 22       mix5  0.9248     0.0739     0.0013     0.0000
# 23       mix6  0.7501     0.2442     0.0057     0.0000
# 24       mix7  0.9906     0.0094     0.0000     0.0000
# 25       mix8  0.9992     0.0008     0.0000     0.0000
# 26       mix9  0.9127     0.0860     0.0013     0.0000
# 27      mix10  0.9637     0.0363     0.0001     0.0000
# 28      mix11  0.8130     0.1730     0.0139     0.0001
# 29      mix12  0.9910     0.0090     0.0001     0.0000
# 30      mix13  0.7774     0.2175     0.0051     0.0000
# 31      mix14  0.7646     0.2286     0.0068     0.0000
# 32      mix15  0.9988     0.0010     0.0001     0.0000
# 33      mix16  0.9937     0.0063     0.0000     0.0000
# 34          .  0.0000     0.0000     0.0000     0.0000
# 35      AMEAN  0.9224     0.0733     0.0041     0.0002
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %% [markdown]
# ## Sensitivity to RTH

# %%
# FIGURE 11

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
sns.set_style("whitegrid")
import matplotlib.ticker as mtick
import matplotlib
# %matplotlib notebook
matplotlib.ticker._mathdefault = lambda x: '\\mathdefault{%s}'%x
import matplotlib.patches as mpatches

#Get Non-Type-3 Fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

legends = ["TRH=2K","TRH=1K","TRH=500"]
                               
#Color Palette
colors = ['#FBD148','#3DB2FF','black', '#34a853']

#Set Font Size
plt.rc('font', size='10')

# Read Dataframe
df = pd.read_csv("../stats_scripts/data/perf_RTH.stat", delimiter='\s+')
print (df)

# Set position of bar on X axis
#barwidth
barWidth = 0.25
r1 = np.arange(len(df.index))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

#Create Plot
fig = plt.figure(figsize=((5,2.25)))
ax = plt.gca()
#Bars
plt.bar(r1, df['2K'], width = barWidth, color=colors[0], label=legends[0],edgecolor='k')
plt.bar(r2, df['1K'], width = barWidth, color=colors[1],label=legends[1],edgecolor='k')
plt.bar(r3, df['500'], width = barWidth, color=colors[2],label=legends[2],edgecolor='k')

#Y=1 Black Line
ax.plot([-0.75,len(df.index)+0.25], [1,1],lw=1.5,color='black')

# Add xticks on the middle of the group bars
#df.at[34,'Expts'] = " "
plt.xticks([(r+barWidth*1) for r in range(len(df.index))], df['RTH'])
ax.set_xlim(-0.75,len(df.index)+0.25)
#plt.xticks(rotation = 30,ha='right')

ax.tick_params(axis='x', which='major', labelsize=8)
for tick in ax.xaxis.get_major_ticks():
    tick_str = tick.label1.get_text()
#    if( (tick_str == "Spec-18") or (tick_str == "Mix-16") or (tick_str == "Amean-34")):
    if( (tick_str == "All-34")):
        tick.label1.set_weight('bold')

#Add Y-axes labels
plt.ylabel('Norm. Performance', size=10)
ax.tick_params(axis='y', which='major', labelsize=10)
ax.tick_params(axis='x', which='major', labelsize=10)
#Set Y format & limts
#ax.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
ax.set_ylim(0.6,1.05)
ax.set_yticks([0.6,0.7,0.8,0.9,1])

#grid
ax.axis('on')
ax.xaxis.grid()

#Legend
leg_handles=[]
for i in range(0,3):
    leg_handles.append(mpatches.Patch(facecolor=colors[i], lw=1, label=legends[i], edgecolor='k'))
plt.legend(handles = leg_handles, bbox_to_anchor=(0.5,1.1),frameon=False,loc='center',ncol=4,prop={'size':11})

#Text
#ax.text(35,1.1, 'Gmean', family='serif',size='9.5',weight='bold',
#        ha='center', va='center')


#Figure
plt.tight_layout()
fig.savefig("sensitivity_rth.pdf",bbox_inches='tight')
plt.show()
# Out:
#             RTH     2K     1K    500
# 0  Spec-Rate-18  0.996  0.975  0.930
# 1   Spec-Mix-16  0.999  0.983  0.934
# 2        All-34  0.998  0.979  0.932
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
# IGNORE

# import matplotlib
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import seaborn as sns; sns.set()
# sns.set_style("whitegrid")
# import matplotlib.ticker as mtick
# import matplotlib
# %matplotlib notebook
# matplotlib.ticker._mathdefault = lambda x: '\\mathdefault{%s}'%x
# import matplotlib.patches as mpatches

# #Get Non-Type-3 Fonts
# matplotlib.rcParams['pdf.fonttype'] = 42
# matplotlib.rcParams['ps.fonttype'] = 42

# legends = ["RRS", "AQUA"]
                               
# #Color Palette
# colors = ['#FBD148','#3DB2FF','black', '#34a853']

# #Set Font Size
# #plt.rc('font', family='serif')
# plt.rc('font', size='9.5')

# # Read Dataframe
# df = pd.read_csv("../stats_scripts/data/mitigations_rrs_rq.stat", delimiter='\s+')
# #print (df)

# # Set position of bar on X axis
# #barwidth
# barWidth = 0.3
# r1 = np.arange(len(df.index))
# r2 = [x + barWidth for x in r1]
# #r3 = [x + barWidth for x in r2]


# # Format for Log ensure 0 becomes 1.
# log_df = df.copy()
# for i in ['RRS','AQUA']:
#     log_df.loc[log_df[i] == 0, i] = 1.2
#     log_df.at[34,i] = 0
# #print (log_df)

# #Create Plot
# fig = plt.figure(figsize=(10,2.5))
# ax = plt.gca()
# #Bars
# plt.bar(r1, log_df['RRS'], width = barWidth, color=colors[0], label=legends[0],edgecolor='k')
# plt.bar(r2, log_df['AQUA'], width = barWidth, color=colors[1],label=legends[1],edgecolor='k')

# #Y=1 Black Line
# #ax.plot([-0.75,len(df.index)+0.25], [1,1],lw=1.5,color='black')

# # Add xticks on the middle of the group bars
# df.at[34,'Expts'] = " "
# plt.xticks([(r+barWidth*1) for r in range(len(df.index))], df['Expts'])
# ax.set_xlim(-0.75,len(df.index)+0.25)
# plt.xticks(rotation = 30,ha='right')
# ax.tick_params(axis='x', which='major', pad=-1)

# ax.tick_params(axis='x', which='major', labelsize=8)
# for tick in ax.xaxis.get_major_ticks():
#     tick_str = tick.label1.get_text()
#     if( (tick_str == "Spec-18") or (tick_str == "Mix-16") or (tick_str == "Amean-34")):
#         tick.label1.set_weight('bold')


# #Add Y-axes labels
# plt.ylabel('Row Migration Per Billion Instr.', size=9.5)
# ax.tick_params(axis='y', which='major', labelsize=8.5)

# #Set Y format & limts
# plt.yscale("log")
# #ax.yaxis.set_major_formatter(mtick.PercentFormatter(1,0))
# ax.set_ylim(1,10**6)
# ax.set_yticks([10,10**2,10**3,10**4,10**5,10**6])

# #grid
# ax.axis('on')
# ax.xaxis.grid()

# #Legend
# leg_handles=[]
# for i in range(0,2):
#     leg_handles.append(mpatches.Patch(facecolor=colors[i], lw=1, label=legends[i], edgecolor='k'))
# plt.legend(handles = leg_handles, bbox_to_anchor=(0.5,1.1),frameon=False,loc='center',ncol=4,prop={'size':10})

# #0 for RRS
# for i in [6,8,12,14,17]:
#     ax.text(i,2, '0',size='7.5',
#             ha='center', va='center')

# #0 for AQUA
# for i in [6,8,10,12,14,16,17,20]:
#     ax.text(i+0.35,2, '0',size='7.5',
#             ha='center', va='center')


# #Figure
# plt.tight_layout()
# fig.savefig("mitigations_aqua.pdf",bbox_inches='tight')
# plt.show()

# IGNORE

##Fig9: Proportional Struct Size sensitivity
# import matplotlib.pyplot as plt
# import csv
# import numpy as np
# import sys
# import matplotlib.patches as mpatches
# import seaborn as sns
# import pandas as pd
# # from plotting_lib import get_color_palette
# hatches = ["", "", "", "",""]
# # colors = ['#4285f4', '#ea4335', 'black', '#34a853']
# # colors = ['#79A3B1','#1687A7','#276678']
# #gist_rath_r
# # colors = ['#F3950D', '#5da04b', '#153878','maroon','#151870']
# colors = ['skyblue', '#5da04b', '#153878','maroon','#753188']
# colors = ['black','#FBD148','#3DB2FF', '#34a853']

# legends = ["TRH=2K","TRH=1K","TRH=500"]

# bench=[]
# qarma=[[]]

# # Read Dataframe
# df = pd.read_csv("../stats_scripts/data/perf_RTH.stat", delimiter='\s+')
# print (df)

# leg_handles=[]
# for i in range(0,3):
#     leg_handles.append(mpatches.Patch(facecolor=colors[i], lw=1, hatch=hatches[i], label=legends[i], edgecolor='k'))

# def subcategorybar(X, vals, width=0.8):
#     n = len(vals)
#     n=6
#     _X = np.arange(len(X))
#     for i in range(3):
#         b = str(i)
#         a = 'core ' + b
#         # print(vals[i])
#         plt.bar(_X + i/float(n)*width, vals[i], edgecolor='k',color=colors[i], 
#                width=width/float(n), linewidth=1, hatch=hatches[i], align="edge",label=legends[i])   
#         # for index, value in enumerate(vals[i]):
#         #     if (index >= 25):
#         #         plt.text(index - width/2 + i/float(n)*width, 3*value, "{:.2f}%".format(value), fontsize=16, 
#         #         bbox=dict(boxstyle='Round', fc='white'), rotation=30)
#     plt.xticks(_X+0.2 , X)
#     axes = plt.gca()
#     axes.tick_params(axis="x",direction="in",pad=10)
#     axes.yaxis.grid(True,color='lightgrey', linewidth=0.5)
# #     axes.yaxis.grid(True,color='k',linewidth=0.2)
#     axes.set_axisbelow(True)
#     plt.xticks(fontsize=tick_font_s, rotation=0, ha='center')
# #     ax.tick_params(axis='x', which='major', pad=15)
#     loc, labels = plt.xticks()
#     yarr = np.arange(0, 101, step=2)
# #     ylabels = ["%0.0f%%" % x for x in yarr]
#     ylabels = [("%0.0f%%" % x) if (x%4==0) else "" for x in yarr]
#     plt.yticks(yarr, ylabels, fontsize=tick_font_s)
# #     plt.xlim([-0.5,4.2])
#     plt.xlim([-0.2,4.7])
#     plt.ylim([0,14])
#     plt.ylabel("Slowdown (%)",fontsize=23)
#     # plt.axhline(y=1.0,label="Baseline", color='black', linestyle='dotted',ms=12.0)
#     for axis in ['top','bottom','left','right']:
#         axes.spines[axis].set_linewidth(2)

# fig = plt.figure(figsize=(10,3))
# tick_font_s=18
# subcategorybar(bench, qarma[0:4])
# plt.legend(handles = leg_handles,handlelength=1.3,handletextpad=0.5, bbox_to_anchor=(0.5,1.15),frameon=False,loc='center',ncol=4,prop={'size':16})
# plt.savefig('1B-rth.pdf',bbox_inches='tight')
# plt.show()
